# %%
# Main Imports
import sys
import deerlab as dl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import time
import XeprAPI
import logging


# Local Imports
sys.path.append("../autoDeer")
from hardware.dummy_xepr import dummy_api as api
import Param_Optimization as po
import DEER_4p as deer
import Tunning as tune
from Logging import setup_logs
setup_logs()

# %%
c_log = logging.getLogger('core')
c_log.setLevel(logging.INFO)
c_log.info('hello')
hw_log = logging.getLogger('hardware')
hw_log.setLevel(logging.INFO)

# %%
xepr = api()
xepr.find_Xepr()
xepr.find_cur_exp()
xepr.find_hidden()

# %%
po.main_run(xepr,[32,16],664,"test","/Users/eth_work/Desktop/")
# Out:
# temp directory already exists
# Carr_purcell_xmax very high: please check!
# xmax estimate is:3625.0ns
# /Users/eth_work/Documents/GitHub/autoDeer/Jupyter Notebooks/../autoDeer/Param_Optimization.py:256: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   cp_fig.show()
# Carr_purcell_xmax very high: please check!
# xmax estimate is:4000.0ns
# /Users/eth_work/Documents/GitHub/autoDeer/Jupyter Notebooks/../autoDeer/Param_Optimization.py:282: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   tau2_fig.show()
#  Maximum tau2 set to 4000 ns
# The optimal pulse delays for 4p DEER are: (507.93650793650795, 4000.0)
# 1

# %%
deer.main_run(xepr,[16,16],[500,200,100],"test","/Users/eth_work/Desktop/",exp_time=0)
# Out:
# DEER Dimension changed to 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/98/m9z1wfmj6t5g87w7sp7451kr0000gn/T/ipykernel_95119/902887024.py in <module>
# ----> 1 deer.main_run(xepr,[16,16],[500,200,100],"test","/Users/eth_work/Desktop/")
#
# ~/Documents/GitHub/autoDeer/Jupyter Notebooks/../autoDeer/DEER_4p.py in main_run(api, ps_length, delays, filename, path)
#     100     run_4pDeer(api,ps_length,delays,[12,2,2],[10,2000,1])
#     101
# --> 102     time.sleep(2*60*60) # This implements the time limit
#     103     api.stop_exp()
#     104
#
# KeyboardInterrupt:
