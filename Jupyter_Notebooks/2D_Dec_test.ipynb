# %% [markdown]
# # 2D Decoherence Graph Testing

# %%
from autoDeer import TwoD_Experiment

# %%
exp = TwoD_Experiment()
exp.load("/Volumes/huka/Data/2D Decoherence/FUS/FUS_H20/2022_01_20_Semi_Auto_Test/2D_dec_FUS267_H20_50K.DSC")
# exp.load("/Volumes/huka/Data/2D Decoherence/FUS/FUS_D20/2022_01_31_FirstLook/2D_dec_FUS267_D20_50K.DSC")

# %%
exp.create_twoD_plot(norm='SNRpShot',contour='Auto')

# %%
exp.optimal_slice_plot(norm='SNRpShot')
